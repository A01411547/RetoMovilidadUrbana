# %%
import pandas as pd

# %%
df = pd.read_csv("viajes_para_ML_sinhoras.csv")

# %%
df
# Out:
#                     dir_o     dir_d  Num_viajes  Unnamed: 0  Num_escuelas  \
# 0                Santiago      Buin           3           1           245
# 1             La Cisterna      Buin         112           1           245
# 2     Pedro Aguirre Cerda      Buin           5           1           245
# 3           Padre Hurtado      Buin          29           1           245
# 4                  Pirque      Buin         141           1           245
# ...                   ...       ...         ...         ...           ...
# 1762             Conchali  Vitacura          97          50            95
# 1763                Lampa  Vitacura          38          50            95
# 1764             Vitacura  Vitacura       39289          50            95
# 1765          San Joaquin  Vitacura          33          50            95
# 1766             Lo Prado  Vitacura          35          50            95
#
#       Num_hospitales  Num_iglesias  Num_zonas_tipicas
# ...

# %%
df2 = df.groupby("dir_d").sum()
df2
# Out:
#                      Num_viajes  Unnamed: 0  Num_escuelas  Num_hospitales  \
# dir_d
# Buin                      55544          30          7350             480
# Calera de Tango           22202          80          2800             160
# Cerrillos                 34936         129          7095             344
# Cerro Navia               50696         156          9555             390
# Colina                   124724         150         10350             450
# Conchali                  46828         222         10915             481
# Curacavi                  37145         196          2800             112
# El Bosque                 58771         336         19320             588
# El Monte                  23723         108          1440              36
# Estacion Central          77737         430         12685             731
# Huechuraba                60560         385          4725             385
# Independencia             23887         444          6845             777
# ...

# %%
df2.to_csv("training_dataset1.csv", index = True)
